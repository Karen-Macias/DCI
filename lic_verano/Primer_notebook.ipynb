# %% [markdown]
# # Este es mi primer notebook

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot  as plt

# %% [markdown]
# Este notebook es demostrativo y contiene algunas ecuaciones como $x^2$

# %%
#aqui defino mis variables
x=np.linspace(-5,5,50)
y=x**2
yerror=1
g=np.cos(x)
h=np.exp(x)

# %%
plt.plot(x,y,label=r'$x^2$')
plt.plot(x,g,label=r'$\cos(x)$')
plt.legend(loc='upper right',frameon=False)

# %%
plt.errorbar(x,g,yerr=yerror,fmt='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#DEfinir funciones
fun=lambda k,h:k**2+h*np.exp(-k)

# %%
x=np.arange(0,10,0.02)
print len(x)
plt.plot(x,fun(x,400))
plt.plot(x,x**2)
# Out:
# 500

# %%
#Otra forma de definir funciones
def fun2(x,h,Label,scale='log'):
    plt.plot(x,h,label=Label)
    plt.yscale(scale)
    plt.legend()
    return

# %%
xx=np.arange(0.01,20,0.1)
yy=np.sin(xx)/xx
fun2(xx,yy,'$sync(x)','linear')

# %%
def sinc(x):
    return np.sin(x)/x

def sinc_(x):
    tmp=x**2+76.
    y=np.sin(tmp)/tmp
    return y

# %%
fun(xx,y)
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# <ipython-input-72-8677e5697a21> in <module>()
# ----> 1 fun(xx,y)
#
# <ipython-input-44-f45eef4b273d> in <lambda>(k, h)
#       1 #DEfinir funciones
# ----> 2 fun=lambda k,h:k**2+h*np.exp(-k)
#
# ValueError: operands could not be broadcast together with shapes (50,) (200,)

# %%
print sinc(xx)
# Out:
# [ 9.99983333e-01  9.97984553e-01  9.92666190e-01  9.84060118e-01
#   9.72217873e-01  9.57210288e-01  9.39126984e-01  9.18075734e-01
#   8.94181697e-01  8.67586527e-01  8.38447371e-01  8.06935753e-01
#   7.73236365e-01  7.37545765e-01  7.00070994e-01  6.61028127e-01
#   6.20640767e-01  5.79138482e-01  5.36755224e-01  4.93727713e-01
#   4.50293813e-01  4.06690915e-01  3.63154329e-01  3.19915705e-01
#   2.77201491e-01  2.35231441e-01  1.94217185e-01  1.54360864e-01
#   1.15853856e-01  7.88755832e-02  4.35924226e-02  1.01567198e-02
#  -2.12940829e-02 -5.06381994e-02 -7.77701308e-02 -1.02601168e-01
#  -1.25059765e-01 -1.45091781e-01 -1.62660589e-01 -1.77747052e-01
#  -1.90349372e-01 -2.00482808e-01 -2.08179269e-01 -2.13486787e-01
#  -2.16468882e-01 -2.17203806e-01 -2.15783693e-01 -2.12313619e-01
#  -2.06910567e-01 -1.99702321e-01 -1.90826298e-01 -1.80428313e-01
#  -1.68661304e-01 -1.55684026e-01 -1.41659709e-01 -1.26754713e-01
# ...

# %%
print sinc_(xx)
# Out:
# [ 7.44985950e-03  7.57827190e-03  7.91512385e-03  8.44447943e-03
#   9.13829330e-03  9.95363769e-03  1.08294886e-02  1.16837847e-02
#   1.24117811e-02  1.28870452e-02  1.29666892e-02  1.25024904e-02
#   1.13592065e-02  9.44046524e-03  6.72089306e-03  3.28060919e-03
#  -6.64950335e-04 -4.75007175e-03 -8.47088671e-03 -1.12361020e-02
#  -1.24626907e-02 -1.17120326e-02 -8.84572683e-03 -4.16158935e-03
#   1.54449703e-03  7.04700604e-03  1.09248141e-02  1.19478242e-02
#   9.53278872e-03  4.11395714e-03 -2.76137872e-03 -8.76230451e-03
#  -1.15403536e-02 -9.72939291e-03 -3.76796981e-03  3.94094309e-03
#   9.83915018e-03  1.08502154e-02  6.14734036e-03 -1.98176304e-03
#  -8.98230384e-03 -1.05170567e-02 -5.33555405e-03  3.40946171e-03
#   9.76609419e-03  8.99999994e-03  1.40708065e-03 -7.26872190e-03
#  -9.93143714e-03 -4.09931562e-03  5.33039705e-03  9.79263530e-03
#   4.88832536e-03 -4.79817578e-03 -9.49664552e-03 -4.12381116e-03
# ...

# %%
plt.plot(xx,sinc(xx),label='sinc(x)')
plt.plot(xx,sinc_(xx),label='sinc_(x)')
plt.title('Prueba')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %%
np.cos(3)
# Out:
# -0.9899924966004454

# %%
np.sqrt(3)
# Out:
# 1.7320508075688772
